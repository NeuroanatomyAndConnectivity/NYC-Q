# %%
import pandas as pd
q_data = pd.read_csv("../data/mriq_all_subs_18_60.csv")
q_data.age.mean()
q_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166 entries, 0 to 165
# Data columns (total 34 columns):
# queried_ursi    166  non-null values
# age             166  non-null values
# sex             166  non-null values
# Q01             166  non-null values
# Q02             166  non-null values
# Q03             166  non-null values
# Q04             166  non-null values
# Q05             166  non-null values
# Q06             166  non-null values
# Q07             166  non-null values
# Q08             166  non-null values
# Q09             166  non-null values
# Q10             166  non-null values
# Q11             166  non-null values
# Q12             166  non-null values
# Q13             166  non-null values
# Q14             166  non-null values
# Q15             166  non-null values
# Q16             166  non-null values
# Q17             166  non-null values
# Q18             166  non-null values
# Q19             166  non-null values
# ...

# %%
import seaborn as sns

# %%
for col_id in [ "Q%02d"%i for i in range(1,31) if i is not 9]:
    figure()
    hist(q_data[col_id], bins=9)

# %%
sns.violin(q_data[q_data.columns[3:26]])

# %%
sns.violin(q_data[q_data.columns[26:]])

# %%
import pandas as pd
f_data = pd.read_csv("../scripts/questionnaire/regressors.csv")
for col_id in ["past", "positive", "future", "negative", "friends", "specific_vague", "words", "images"]:
    figure()
    hist(f_data[col_id], bins=20)
    plt.xlabel(col_id)
    plt.ylabel("subject count")

# %%
sns.violin(f_data[f_data.columns[7:15]])

# %%
from scipy import stats
import numpy as np
d1 = stats.norm(0, 5).rvs(100)
d2 = np.concatenate([stats.gamma(4).rvs(50),
                     -1 * stats.gamma(4).rvs(50)])
data = pd.DataFrame(dict(d1=d1, d2=d2))

# %%
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 2 columns):
# d1    100  non-null values
# d2    100  non-null values
# dtypes: float64(2)

# %%
import dateutil
df_mri = pd.read_csv("/Users/filo/Dropbox/Public/example1/3760_MRI Log Sheet_20131129.csv", skiprows=1, 
                 converters={"MRI_04":dateutil.parser.parse},
                 index_col=0)

# %%
df.MRI_04 < dateutil.parser.parse("12:00")
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# ...
# 250    False
# 251     True
# 252    False
# 253     True
# 254     True
# 255    False
# 256    False
# 257     True
# 258     True
# 259    False
# 260    False
# 261    False
# 262    False
# 263     True
# 264    False
# Name: MRI_04, Length: 265, dtype: bool

# %%
df_age = pd.read_csv("/Users/filo/Dropbox/Public/example1/3760_Age_20131129.csv", skiprows=1,
                 index_col=0)

# %%
dateutil.parser.parse?
